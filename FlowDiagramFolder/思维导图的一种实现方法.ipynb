# %%
from graphviz import Digraph

# %%
dot=Digraph("test",'comment',None,None,'svg',None,"UTF-8",{'rankdir':'LR'},  
              {'color':'black','fontcolor':'black','fontname':'FangSong','fontsize':'12','style':'rounded','shape':'box'},
           {'color':'#999999','fontcolor':'#888888','fontsize':'10','fontname':'FangSong'},None,False)

# %% [markdown]
# #因为Graph这个节点在后面和别的点连接的比较多，所以简写为g
# #下面这句话实际是dot.node("g",label="Graph")
# dot.node("g","这可行", {'color':'red','fontcolor':'red'})
# dot.node('a','Session', shape="circle")
# #不用简写的直接采用label来表示
# dot.edge("a","g"," 这里可以写操作")
# dot.edge("g","Placeholder",dir="both")
# dot.edge("g", "Variable", )

# %%
dot.node('1','样品的分类', {'color':'red','fontcolor':'red'})
dot.node('2','四电极 Top gate InSe 样品')
dot.node('3','四电极 Side gate InSe 样品')
dot.node('4','四电极 Top gate CdO 样品')
dot.node('5','只有两电极 InSe 样品')

# %%
dot.edge('1','2')
dot.edge('1','3')
dot.edge('1','4')
dot.edge('1','5')

# %%
dot

# %%
dot.view()
# Out:
# 'test.gv.svg'
